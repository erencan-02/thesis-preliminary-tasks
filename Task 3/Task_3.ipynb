# %% [markdown]
# # Task 3 - Point Cloud Scenes
#
# Visualizing large-scale point cloud scenes is important when qualitatively evaluating predictions from a machine learning model or exploring what is happening in an outdoor scene. To this end, using Python and Open3D (http://www.open3d.org/docs/release/getting_started.html), implement a visualization of a LiDAR point cloud sequence from the SemanticKITTI dataset. Your implementation should 1) allow you to navigate forward and backward in time using the left and right arrow keys, and 2) visualize the semantic labels for each point. An example visualization is shown in the following video (semantic labels on the left): https://www.youtube.com/watch?v=VRZGAK3XpX0.

# %%
import os
import open3d as o3d
import numpy as np
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %% [markdown]
# # Helper Functions

# %%
color_map = {
   0 : [0, 0, 0],
  1 : [0, 0, 255],
  10: [245, 150, 100],
  11: [245, 230, 100],
  13: [250, 80, 100],
  15: [150, 60, 30],
  16: [255, 0, 0],
  18: [180, 30, 80],
  20: [255, 0, 0],
  30: [30, 30, 255],
  31: [200, 40, 255],
  32: [90, 30, 150],
  40: [255, 0, 255],
  44: [255, 150, 255],
  48: [75, 0, 75],
  49: [75, 0, 175],
  50: [0, 200, 255],
  51: [50, 120, 255],
  52: [0, 150, 255],
  60: [170, 255, 150],
  70: [0, 175, 0],
  71: [0, 60, 135],
  72: [80, 240, 150],
  80: [150, 240, 255],
  81: [0, 0, 255],
  99: [255, 255, 50],
  252: [245, 150, 100],
  256: [255, 0, 0],
  253: [200, 40, 255],
  254: [30, 30, 255],
  255: [90, 30, 150],
  257: [250, 80, 100],
  258: [180, 30, 80],
  259: [255, 0, 0]
}

def get_path(task_number, *args):
    notebook_path = os.path.abspath(f"Task_{task_number}.ipynb")
    return os.path.join(os.path.dirname(notebook_path), *args)


def label_to_color(label: np.uint32):
    global color_map
    
    if label not in color_map:
        return np.array([0, 0, 0])
    
    return np.array(color_map[label])


def load_point_clouds(save_dir):
    pcds = []
    
    for filename in sorted(os.listdir(save_dir)):
        try:
            pcd = o3d.io.read_point_cloud(os.path.join(save_dir, filename))
            pcds.append(pcd)
        except:
            continue
    
    return pcds


def bin_to_point_cloud(bin_file_path, label_file_path, show_instance_labels=False):
    # Load the .bin data into a numpy array
    point_cloud_np = np.fromfile(bin_file_path, dtype=np.float32)
    labels = np.fromfile(label_file_path, dtype=np.uint32)
    
    # Reshape the numpy array to Nx4 (x, y, z, intensity)
    point_cloud_np = point_cloud_np.reshape(-1, 4)
    labels = labels.reshape(-1, 1)
    
    # Separate the semantic labels and the instance labels
    lables =  labels >> 16  if show_instance_labels else labels & 0xFFFF
    
    # Create an Open3D point cloud object
    point_cloud_o3d = o3d.geometry.PointCloud()
    
    # Set the points of the point cloud from the numpy array
    point_cloud_o3d.points = o3d.utility.Vector3dVector(point_cloud_np[:, :3])
    point_cloud_o3d.colors = o3d.utility.Vector3dVector(np.array([label_to_color(int(label[0])) for label in lables]))
    
    return point_cloud_o3d

# %% [markdown]
# # Generate o3d Point Clouds From Dataset
#
#
# ### 1. Read .bin file
# ### 2. Convert into o3d Point Cloud
# ### 3. Save to .ply file

# %%
SAVE_DIR = get_path(3, "save", "normal")
SEQ_DIR = get_path(3, "data", "normal", "dataset", "sequences")
SEQ = ["00"]

for seq in SEQ:
  velodyne_dir = os.path.join(SEQ_DIR, seq, "velodyne")
  labels_dir = os.path.join(SEQ_DIR, seq, "labels")
  
  for file_name in sorted(os.listdir(velodyne_dir)):
    if file_name.endswith(".bin"):
      bin_file_path = os.path.join(velodyne_dir, file_name)
      label_file_path = os.path.join(labels_dir, file_name[:-4] + ".label")
      
      save_file_name = f"{seq}_{file_name[:-4]}.ply"
      save_file_path = os.path.join(SAVE_DIR, seq, save_file_name)
      
      # check if file already exists
      if os.path.isfile(save_file_path):
        print(f"Point Cloud for {save_file_name} already exists. Skipping...")
        continue
      
      if not os.path.exists(os.path.join(SAVE_DIR, seq)):
        os.makedirs(os.path.join(SAVE_DIR, seq))
      
      # Convert to Open3D point cloud
      print("Generating Voxel Grid for " + save_file_name)
      pcd = bin_to_point_cloud(bin_file_path, label_file_path)
      
      # Save point cloud to file
      print(f"Saving Point Cloud to {save_file_path}")
      o3d.io.write_point_cloud(save_file_path, pcd)
# Out:
# Point Cloud for 00_000000.ply already exists. Skipping...
# Point Cloud for 00_000001.ply already exists. Skipping...
# Point Cloud for 00_000002.ply already exists. Skipping...
# Point Cloud for 00_000003.ply already exists. Skipping...
# Point Cloud for 00_000004.ply already exists. Skipping...
# Point Cloud for 00_000005.ply already exists. Skipping...
# Point Cloud for 00_000006.ply already exists. Skipping...
# Point Cloud for 00_000007.ply already exists. Skipping...
# Point Cloud for 00_000008.ply already exists. Skipping...
# Point Cloud for 00_000009.ply already exists. Skipping...
# Point Cloud for 00_000010.ply already exists. Skipping...
# Point Cloud for 00_000011.ply already exists. Skipping...
# Point Cloud for 00_000012.ply already exists. Skipping...
# Point Cloud for 00_000013.ply already exists. Skipping...
# Point Cloud for 00_000014.ply already exists. Skipping...
# Point Cloud for 00_000015.ply already exists. Skipping...
# Point Cloud for 00_000016.ply already exists. Skipping...
# Point Cloud for 00_000017.ply already exists. Skipping...
# Point Cloud for 00_000018.ply already exists. Skipping...
# Point Cloud for 00_000019.ply already exists. Skipping...
# Point Cloud for 00_000020.ply already exists. Skipping...
# Point Cloud for 00_000021.ply already exists. Skipping...
# Point Cloud for 00_000022.ply already exists. Skipping...
# Point Cloud for 00_000023.ply already exists. Skipping...
# Point Cloud for 00_000024.ply already exists. Skipping...
# Point Cloud for 00_000025.ply already exists. Skipping...
# Point Cloud for 00_000026.ply already exists. Skipping...
# Point Cloud for 00_000027.ply already exists. Skipping...
# Point Cloud for 00_000028.ply already exists. Skipping...
# Point Cloud for 00_000029.ply already exists. Skipping...
# Point Cloud for 00_000030.ply already exists. Skipping...
# Point Cloud for 00_000031.ply already exists. Skipping...
# Point Cloud for 00_000032.ply already exists. Skipping...
# Point Cloud for 00_000033.ply already exists. Skipping...
# Point Cloud for 00_000034.ply already exists. Skipping...
# Point Cloud for 00_000035.ply already exists. Skipping...
# Point Cloud for 00_000036.ply already exists. Skipping...
# Point Cloud for 00_000037.ply already exists. Skipping...
# Point Cloud for 00_000038.ply already exists. Skipping...
# Point Cloud for 00_000039.ply already exists. Skipping...
# Point Cloud for 00_000040.ply already exists. Skipping...
# Point Cloud for 00_000041.ply already exists. Skipping...
# Point Cloud for 00_000042.ply already exists. Skipping...
# Point Cloud for 00_000043.ply already exists. Skipping...
# Point Cloud for 00_000044.ply already exists. Skipping...
# Point Cloud for 00_000045.ply already exists. Skipping...
# Point Cloud for 00_000046.ply already exists. Skipping...
# Point Cloud for 00_000047.ply already exists. Skipping...
# Point Cloud for 00_000048.ply already exists. Skipping...
# Point Cloud for 00_000049.ply already exists. Skipping...
# Point Cloud for 00_000050.ply already exists. Skipping...
# Point Cloud for 00_000051.ply already exists. Skipping...
# Point Cloud for 00_000052.ply already exists. Skipping...
# Point Cloud for 00_000053.ply already exists. Skipping...
# Point Cloud for 00_000054.ply already exists. Skipping...
# Point Cloud for 00_000055.ply already exists. Skipping...
# Point Cloud for 00_000056.ply already exists. Skipping...
# Point Cloud for 00_000057.ply already exists. Skipping...
# Point Cloud for 00_000058.ply already exists. Skipping...
# Point Cloud for 00_000059.ply already exists. Skipping...
# Point Cloud for 00_000060.ply already exists. Skipping...
# Point Cloud for 00_000061.ply already exists. Skipping...
# Point Cloud for 00_000062.ply already exists. Skipping...
# Point Cloud for 00_000063.ply already exists. Skipping...
# Point Cloud for 00_000064.ply already exists. Skipping...
# Point Cloud for 00_000065.ply already exists. Skipping...
# Point Cloud for 00_000066.ply already exists. Skipping...
# Point Cloud for 00_000067.ply already exists. Skipping...
# Point Cloud for 00_000068.ply already exists. Skipping...
# Point Cloud for 00_000069.ply already exists. Skipping...
# Point Cloud for 00_000070.ply already exists. Skipping...
# Point Cloud for 00_000071.ply already exists. Skipping...
# Point Cloud for 00_000072.ply already exists. Skipping...
# Point Cloud for 00_000073.ply already exists. Skipping...
# Point Cloud for 00_000074.ply already exists. Skipping...
# Point Cloud for 00_000075.ply already exists. Skipping...
# Point Cloud for 00_000076.ply already exists. Skipping...
# Point Cloud for 00_000077.ply already exists. Skipping...
# Point Cloud for 00_000078.ply already exists. Skipping...
# Point Cloud for 00_000079.ply already exists. Skipping...
# Point Cloud for 00_000080.ply already exists. Skipping...
# Point Cloud for 00_000081.ply already exists. Skipping...
# Point Cloud for 00_000082.ply already exists. Skipping...
# Point Cloud for 00_000083.ply already exists. Skipping...
# Point Cloud for 00_000084.ply already exists. Skipping...
# Point Cloud for 00_000085.ply already exists. Skipping...
# Point Cloud for 00_000086.ply already exists. Skipping...
# Point Cloud for 00_000087.ply already exists. Skipping...
# Point Cloud for 00_000088.ply already exists. Skipping...
# Point Cloud for 00_000089.ply already exists. Skipping...
# Point Cloud for 00_000090.ply already exists. Skipping...
# Point Cloud for 00_000091.ply already exists. Skipping...
# Point Cloud for 00_000092.ply already exists. Skipping...
# Point Cloud for 00_000093.ply already exists. Skipping...
# Point Cloud for 00_000094.ply already exists. Skipping...
# Point Cloud for 00_000095.ply already exists. Skipping...
# Point Cloud for 00_000096.ply already exists. Skipping...
# Point Cloud for 00_000097.ply already exists. Skipping...
# Point Cloud for 00_000098.ply already exists. Skipping...
# Point Cloud for 00_000099.ply already exists. Skipping...
# Point Cloud for 00_000100.ply already exists. Skipping...
# Point Cloud for 00_000101.ply already exists. Skipping...
# Point Cloud for 00_000102.ply already exists. Skipping...
# Point Cloud for 00_000103.ply already exists. Skipping...
# Point Cloud for 00_000104.ply already exists. Skipping...
# Point Cloud for 00_000105.ply already exists. Skipping...
# Point Cloud for 00_000106.ply already exists. Skipping...
# Point Cloud for 00_000107.ply already exists. Skipping...
# Point Cloud for 00_000108.ply already exists. Skipping...
# Point Cloud for 00_000109.ply already exists. Skipping...
# Point Cloud for 00_000110.ply already exists. Skipping...
# Point Cloud for 00_000111.ply already exists. Skipping...
# Point Cloud for 00_000112.ply already exists. Skipping...
# Point Cloud for 00_000113.ply already exists. Skipping...
# Point Cloud for 00_000114.ply already exists. Skipping...
# Point Cloud for 00_000115.ply already exists. Skipping...
# Point Cloud for 00_000116.ply already exists. Skipping...
# Point Cloud for 00_000117.ply already exists. Skipping...
# Point Cloud for 00_000118.ply already exists. Skipping...
# Point Cloud for 00_000119.ply already exists. Skipping...
# Point Cloud for 00_000120.ply already exists. Skipping...
# Point Cloud for 00_000121.ply already exists. Skipping...
# Point Cloud for 00_000122.ply already exists. Skipping...
# Point Cloud for 00_000123.ply already exists. Skipping...
# Point Cloud for 00_000124.ply already exists. Skipping...
# Point Cloud for 00_000125.ply already exists. Skipping...
# Point Cloud for 00_000126.ply already exists. Skipping...
# Point Cloud for 00_000127.ply already exists. Skipping...
# Generating Voxel Grid for 00_000128.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000128.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000129.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000129.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000130.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000130.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000131.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000131.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000132.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000132.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000133.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000133.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000134.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000134.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000135.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000135.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000136.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000136.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000137.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000137.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000138.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000138.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000139.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000139.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000140.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000140.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000141.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000141.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000142.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000142.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000143.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000143.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000144.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000144.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000145.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000145.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000146.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000146.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000147.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000147.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000148.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000148.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000149.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000149.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000150.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000150.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000151.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000151.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000152.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000152.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000153.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000153.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000154.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000154.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000155.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000155.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000156.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000156.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000157.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000157.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000158.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000158.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000159.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000159.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000160.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000160.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000161.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000161.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000162.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000162.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000163.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000163.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000164.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000164.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000165.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000165.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000166.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000166.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000167.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000167.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000168.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000168.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000169.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000169.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000170.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000170.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000171.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000171.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000172.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000172.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000173.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000173.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000174.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000174.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000175.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000175.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000176.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000176.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000177.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000177.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000178.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000178.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000179.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000179.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000180.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000180.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000181.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000181.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000182.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000182.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000183.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000183.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000184.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000184.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000185.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000185.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000186.ply
# Saving Point Cloud to c:\Users\Admin\Desktop\Uni\Thesis\Preliminary Tasks\Task 3\save\normal\00\00_000186.ply
# [Open3D WARNING] Write Ply clamped color value to valid range
# Generating Voxel Grid for 00_000187.ply
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 27
#      25 # Convert to Open3D point cloud
#      26 print("Generating Voxel Grid for " + save_file_name)
# ---> 27 pcd = bin_to_point_cloud(bin_file_path, label_file_path)
#      29 # Save point cloud to file
#      30 print(f"Saving Point Cloud to {save_file_path}")
#
# Cell In[2], line 79, in bin_to_point_cloud(bin_file_path, label_file_path, show_instance_labels)
#      77 # Set the points of the point cloud from the numpy array
#      78 point_cloud_o3d.points = o3d.utility.Vector3dVector(point_cloud_np[:, :3])
# ---> 79 point_cloud_o3d.colors = o3d.utility.Vector3dVector(np.array([label_to_color(int(label[0])) for label in lables]))
#      81 return point_cloud_o3d
#
# Cell In[2], line 79, in <listcomp>(.0)
#      77 # Set the points of the point cloud from the numpy array
#      78 point_cloud_o3d.points = o3d.utility.Vector3dVector(point_cloud_np[:, :3])
# ---> 79 point_cloud_o3d.colors = o3d.utility.Vector3dVector(np.array([label_to_color(int(label[0])) for label in lables]))
#      81 return point_cloud_o3d
#
# Cell In[2], line 43, in label_to_color(label)
#      39     notebook_path = os.path.abspath(f"Task_{task_number}.ipynb")
#      40     return os.path.join(os.path.dirname(notebook_path), *args)
# ---> 43 def label_to_color(label: np.uint32):
#      44     global color_map
#      46     if label not in color_map:
#
# KeyboardInterrupt:

# %% [markdown]
# # Run Open3D Visualization

# %%
# Load all saved voxel grids
SAVE_DIR = get_path(3, "save", "normal", "00")
point_clouds = load_point_clouds(SAVE_DIR)

# Create a visualizer and window
vis = o3d.visualization.VisualizerWithKeyCallback()
vis.create_window(width=1000, height=1000)
view_control = vis.get_view_control()

# Add the first point cloud to the visualizer
vis.add_geometry(point_clouds[0])

# This index will keep track of the current point cloud
idx = 0


# Define the functions to be called when the left or right arrow key is pressed
def left_key_action(vis):
    global idx
    
    camera_parameters = vis.get_view_control().convert_to_pinhole_camera_parameters()

    idx = (idx - 1) % len(point_clouds)
    vis.clear_geometries()
    vis.add_geometry(point_clouds[idx])
    
    # Restore the camera parameters
    view_control.convert_from_pinhole_camera_parameters(camera_parameters, True)
    vis.update_renderer()
    
def right_key_action(vis):
    global idx

    camera_parameters = vis.get_view_control().convert_to_pinhole_camera_parameters()

    idx = (idx + 1) % len(point_clouds)
    vis.clear_geometries()
    vis.add_geometry(point_clouds[idx])
    
    # Restore the camera parameters
    view_control.convert_from_pinhole_camera_parameters(camera_parameters, True)
    vis.update_renderer()

# Bind the functions to the left and right arrow keys
vis.register_key_callback(262, right_key_action)  
vis.register_key_callback(263, left_key_action)  

# Start the visualization
vis.run()
vis.destroy_window()
# Out:
# [Open3D WARNING] Read PLY failed: unable to parse header.
# [Open3D WARNING] The number of points is 0 when creating axis-aligned bounding box.
# [Open3D WARNING] The number of points is 0 when creating axis-aligned bounding box.
# [Open3D WARNING] The number of points is 0 when creating axis-aligned bounding box.
# [Open3D WARNING] The number of points is 0 when creating axis-aligned bounding box.
# [Open3D WARNING] The number of points is 0 when creating axis-aligned bounding box.
# [Open3D WARNING] The number of points is 0 when creating axis-aligned bounding box.
# [Open3D WARNING] The number of points is 0 when creating axis-aligned bounding box.
# [Open3D WARNING] The number of points is 0 when creating axis-aligned bounding box.
# [Open3D WARNING] The number of points is 0 when creating axis-aligned bounding box.
# [Open3D WARNING] The number of points is 0 when creating axis-aligned bounding box.
# [Open3D WARNING] The number of points is 0 when creating axis-aligned bounding box.
# [Open3D WARNING] The number of points is 0 when creating axis-aligned bounding box.
# [Open3D WARNING] The number of points is 0 when creating axis-aligned bounding box.
# [Open3D WARNING] The number of points is 0 when creating axis-aligned bounding box.
# [Open3D WARNING] The number of points is 0 when creating axis-aligned bounding box.
# [Open3D WARNING] The number of points is 0 when creating axis-aligned bounding box.
# [Open3D WARNING] The number of points is 0 when creating axis-aligned bounding box.
# [Open3D WARNING] The number of points is 0 when creating axis-aligned bounding box.
# [Open3D WARNING] The number of points is 0 when creating axis-aligned bounding box.
# [Open3D WARNING] The number of points is 0 when creating axis-aligned bounding box.
# [Open3D WARNING] The number of points is 0 when creating axis-aligned bounding box.
# [Open3D WARNING] The number of points is 0 when creating axis-aligned bounding box.
